# %%
using Revise
using Pkg
Pkg.activate("C:/Users/lisah/Documents/Repos/ma-code")
includet("c:/Users/lisah/Documents/Repos/ma-code/src/src.jl")
using .Src

# %%
path_fi = "C:/Users/lisah/Documents/Repos/ma-code/data/t_fixed/t100/fisher_am/"

# %%
# general setup
prm_keys=[:a, :m]
M_vals = [500,100,50]
noise_vals = [0.01,0.1,0.5]
t_fixed=true

# %%
# gen fisher data
# TODO: redo with N=2
N=1 # no mult restart
#gen_all_fish_data_an0_plane(prm_keys, M_vals, noise_vals, path_fi, t_fixed=t_fixed, N=N)

# %%
path_ll = "C:/Users/lisah/Documents/Repos/ma-code/data/t_fixed/t100/ll_am/"

# %%
# compute likelihood evals for points
points = [[0.5,0.45],[0.9,0.45],[1.5,0.45]]
n0=1.5

#gen_store_ll_data(points, prm_keys, M_vals, noise_vals, path_ll, n0=n0, t_fixed=t_fixed)

# %% [markdown]
# ## Likelihood plots

# %%
# noise increases top->bottom
# sample size decreases left->right
#plot_ll_grid([0.5,0.45],prm_keys, noise_vals, M_vals, -10000, path_ll, n0=1.5)

# %%
# noise increases top->bottom
# sample size decreases left->right
#plot_ll_grid([0.9,0.45],prm_keys, noise_vals, M_vals, -10000, path_ll, n0=1.5)

# %%
# noise increases top->bottom
# sample size decreases left->right
#plot_ll_grid([1.5,0.45],prm_keys, noise_vals, M_vals, -10000, path_ll, n0=1.5)

# %% [markdown]
# ## Fisher information

# %%
# noise increases top->bottom
# sample size decreases left->right
#plot_fisher_grid(noise_vals,M_vals,path_fi)
