# %%
using Pkg
Pkg.activate("C:/Users/lisah/Documents/Repos/ma-code")
# Out:
#   Activating project at `C:\Users\lisah\Documents\Repos\ma-code`

# %%
include("c:/Users/lisah/Documents/Repos/ma-code/src/src.jl")
using .Src

# %%
using JLD2, Distributions

# %% [markdown]
# ## Computation of Sobol Indices

# %%
N = 5000
t_fixed = true
t_end = 100.0
M = Int(t_end * 10); # pick M solution trajectory time points for computing indices

# %% [markdown]
# ### analysis for different parameter densities

# %%
# define densities that are consistent
dens_m = Uniform(0.45-0.45*0.05,0.45+0.45*0.05)
dens_w0 = Uniform(0.0,2.0);

# %% [markdown]
# #### a left of bif pt

# %%
dens_a = Uniform(0.0,0.85)
dens_n0 = Uniform(0.0, 2.0)
sobol_n, sobol_w = compute_sobol_indices(N, dens_a, dens_m, dens_w0, dens_n0, M, t_fixed, t_end)
# Out:
# Calculating indices for 4 parameters ... 100%|███████████| Time: 0:00:04
# Calculating indices for 4 parameters ... 100%|███████████| Time: 0:00:03
# Calculating indices for 4 parameters ... 100%|███████████| Time: 0:00:04
# Calculating indices for 4 parameters ... 100%|███████████| Time: 0:00:03
# Calculating indices for 4 parameters ... 100%|███████████| Time: 0:00:03
# Calculating indices for 4 parameters ... 100%|███████████| Time: 0:00:03
# Calculating indices for 4 parameters ... 100%|███████████| Time: 0:00:03
# Calculating indices for 4 parameters ... 100%|███████████| Time: 0:00:06
# Calculating indices for 4 parameters ... 100%|███████████| Time: 0:00:16
# Calculating indices for 4 parameters ... 100%|███████████| Time: 0:00:03
# Calculating indices for 4 parameters ... 100%|███████████| Time: 0:00:03
# Calculating indices for 4 parameters ... 100%|███████████| Time: 0:00:03
# Calculating indices for 4 parameters ... 100%|███████████| Time: 0:00:03
# ...

# %%
# store
@save "C:/Users/lisah/Documents/Repos/ma-code/temp_saves/global_inits/dl/sobol_n_$(N)_$(t_end)_$(M)_v2.jld2" sobol_n
@save "C:/Users/lisah/Documents/Repos/ma-code/temp_saves/global_inits/dl/sobol_w_$(N)_$(t_end)_$(M)_v2.jld2" sobol_w

# %%
# smaller range of n0
dens_a = Uniform(0.0, 0.85)
dens_n0 = Uniform(0.5,2.0)
sobol_n, sobol_w = compute_sobol_indices(N, dens_a, dens_m, dens_w0, dens_n0, M, t_fixed, t_end)
# Out:
# (Dict{Symbol, Array}[Dict(:firstorder => [0.0, 0.0, 0.0, 1.0004918029726286], :secondorder_conf => Union{Missing, Float64}[missing 0.0 0.0 1.5577898174627858e-16; missing missing 0.0 1.5577898174627858e-16; missing missing missing 1.5577898174627858e-16; missing missing missing missing], :totalorder_conf => [0.0, 0.0, 0.0, 0.028186155427949604], :totalorder => [0.0, 0.0, 0.0, 1.0004849713305852], :firstorder_conf => [0.0, 0.0, 0.0, 0.034871363396310126], :secondorder => Union{Missing, Float64}[missing 0.0 0.0 0.0; missing missing 0.0 0.0; missing missing missing 0.0; missing missing missing missing]), Dict(:firstorder => [1.7634814629338376e-5, 4.171204823801681e-6, 0.03802951445361007, 0.947964785695796], :secondorder_conf => Union{Missing, Float64}[missing 0.00033874408412161027 0.00034910797951918877 0.0004130374299823598; missing missing 0.00022969839633145834 0.00028822697887466236; missing missing missing 0.01751229975204889; missing missing missing missing], :totalorder_conf =
# ...

# %%
# store
@save "C:/Users/lisah/Documents/Repos/ma-code/temp_saves/local_inits/dl/sobol_n_$(N)_$(t_end)_$(M)_v2.jld2" sobol_n
@save "C:/Users/lisah/Documents/Repos/ma-code/temp_saves/local_inits/dl/sobol_w_$(N)_$(t_end)_$(M)_v2.jld2" sobol_w

# %% [markdown]
# #### a around bif pt

# %%
dens_a = Uniform(0.85,0.95)
dens_n0 = Uniform(0.0, 2.0)
sobol_n, sobol_w = compute_sobol_indices(N, dens_a, dens_m, dens_w0, dens_n0, M, t_fixed, t_end)
# Out:
# (Dict{Symbol, Array}[Dict(:firstorder => [0.0, 0.0, 0.0, 1.0004918029726284], :secondorder_conf => Union{Missing, Float64}[missing 0.0 0.0 1.5365955359966152e-16; missing missing 0.0 1.5365955359966152e-16; missing missing missing 1.5365955359966152e-16; missing missing missing missing], :totalorder_conf => [0.0, 0.0, 0.0, 0.027217617515243247], :totalorder => [0.0, 0.0, 0.0, 1.000484971330585], :firstorder_conf => [0.0, 0.0, 0.0, 0.03272892063415511], :secondorder => Union{Missing, Float64}[missing 0.0 0.0 0.0; missing missing 0.0 0.0; missing missing missing 0.0; missing missing missing missing]), Dict(:firstorder => [2.0768698724436072e-7, -5.258484793110182e-7, 0.013724621405602743, 0.9761565221194967], :secondorder_conf => Union{Missing, Float64}[missing 2.9078189967107557e-5 2.966231587105903e-5 3.393928892318326e-5; missing missing 0.00017023046776076318 0.00020150415628286255; missing missing missing 0.012799653339997203; missing missing missing missing], :totalorder_conf => 
# ...

# %%
# store
@save "C:/Users/lisah/Documents/Repos/ma-code/temp_saves/global_inits/dm/sobol_n_$(N)_$(t_end)_$(M)_v2.jld2" sobol_n
@save "C:/Users/lisah/Documents/Repos/ma-code/temp_saves/global_inits/dm/sobol_w_$(N)_$(t_end)_$(M)_v2.jld2" sobol_w

# %%
# smaller range of n0
dens_a = Uniform(0.85, 0.95)
dens_n0 = Uniform(0.5,2.0)
sobol_n, sobol_w = compute_sobol_indices(N, dens_a, dens_m, dens_w0, dens_n0, M, t_fixed, t_end)
# Out:
# (Dict{Symbol, Array}[Dict(:firstorder => [0.0, 0.0, 0.0, 1.0004918029726286], :secondorder_conf => Union{Missing, Float64}[missing 0.0 0.0 1.5949350155364167e-16; missing missing 0.0 1.5949350155364167e-16; missing missing missing 1.5949350155364167e-16; missing missing missing missing], :totalorder_conf => [0.0, 0.0, 0.0, 0.02793648070490959], :totalorder => [0.0, 0.0, 0.0, 1.0004849713305852], :firstorder_conf => [0.0, 0.0, 0.0, 0.03330620406735009], :secondorder => Union{Missing, Float64}[missing 0.0 0.0 0.0; missing missing 0.0 0.0; missing missing missing 0.0; missing missing missing missing]), Dict(:firstorder => [5.8263328700756216e-8, 4.190597655555474e-6, 0.038104889214747244, 0.9478475610251251], :secondorder_conf => Union{Missing, Float64}[missing 4.059942838920476e-5 4.218265961590956e-5 4.930557852518795e-5; missing missing 0.0002423268722811437 0.00029588547089909176; missing missing missing 0.018065778741210924; missing missing missing missing], :totalorder_conf => [2.
# ...

# %%
# store
@save "C:/Users/lisah/Documents/Repos/ma-code/temp_saves/local_inits/dm/sobol_n_$(N)_$(t_end)_$(M)_v2.jld2" sobol_n
@save "C:/Users/lisah/Documents/Repos/ma-code/temp_saves/local_inits/dm/sobol_w_$(N)_$(t_end)_$(M)_v2.jld2" sobol_w

# %% [markdown]
# #### a right of bif pt

# %%
dens_a = Uniform(0.95, 2.0)
dens_n0 = Uniform(0.0, 2.0)
sobol_n, sobol_w = compute_sobol_indices(N, dens_a, dens_m, dens_w0, dens_n0, M, t_fixed, t_end)
# Out:
# (Dict{Symbol, Array}[Dict(:firstorder => [0.0, 0.0, 0.0, 1.0004918029726284], :secondorder_conf => Union{Missing, Float64}[missing 0.0 0.0 1.64756796503953e-16; missing missing 0.0 1.64756796503953e-16; missing missing missing 1.64756796503953e-16; missing missing missing missing], :totalorder_conf => [0.0, 0.0, 0.0, 0.0283945177913417], :totalorder => [0.0, 0.0, 0.0, 1.000484971330585], :firstorder_conf => [0.0, 0.0, 0.0, 0.032520728265107046], :secondorder => Union{Missing, Float64}[missing 0.0 0.0 0.0; missing missing 0.0 0.0; missing missing missing 0.0; missing missing missing missing]), Dict(:firstorder => [1.2034446903446992e-5, -6.157688131192128e-7, 0.013774943575024817, 0.9759883871114637], :secondorder_conf => Union{Missing, Float64}[missing 0.00029689259805528974 0.00030175673959658653 0.0003662173168198265; missing missing 0.0001700721500106526 0.00020001051949903524; missing missing missing 0.012646307358819393; missing missing missing missing], :totalorder_conf => [1.3
# ...

# %%
# store
@save "C:/Users/lisah/Documents/Repos/ma-code/temp_saves/global_inits/dr/sobol_n_$(N)_$(t_end)_$(M)_v2.jld2" sobol_n
@save "C:/Users/lisah/Documents/Repos/ma-code/temp_saves/global_inits/dr/sobol_w_$(N)_$(t_end)_$(M)_v2.jld2" sobol_w

# %%
# smaller range of n0
dens_a = Uniform(0.95, 2.0)
dens_n0 = Uniform(0.5,2.0)
sobol_n, sobol_w = compute_sobol_indices(N, dens_a, dens_m, dens_w0, dens_n0, M, t_fixed, t_end)
# Out:
# (Dict{Symbol, Array}[Dict(:firstorder => [0.0, 0.0, 0.0, 1.0004918029726286], :secondorder_conf => Union{Missing, Float64}[missing 0.0 0.0 1.6199567733990288e-16; missing missing 0.0 1.6199567733990288e-16; missing missing missing 1.6199567733990288e-16; missing missing missing missing], :totalorder_conf => [0.0, 0.0, 0.0, 0.027889340027590845], :totalorder => [0.0, 0.0, 0.0, 1.0004849713305852], :firstorder_conf => [0.0, 0.0, 0.0, 0.03370885001793438], :secondorder => Union{Missing, Float64}[missing 0.0 0.0 0.0; missing missing 0.0 0.0; missing missing missing 0.0; missing missing missing missing]), Dict(:firstorder => [2.777849644301861e-5, 4.104547349597135e-6, 0.038178886263300696, 0.9476242877512565], :secondorder_conf => Union{Missing, Float64}[missing 0.00044458754654663096 0.0004608934405110235 0.000530899706716476; missing missing 0.00022977757974358012 0.00029897850779811376; missing missing missing 0.01844248348577431; missing missing missing missing], :totalorder_conf => 
# ...

# %%
# store
@save "C:/Users/lisah/Documents/Repos/ma-code/temp_saves/local_inits/dr/sobol_n_$(N)_$(t_end)_$(M)_v2.jld2" sobol_n
@save "C:/Users/lisah/Documents/Repos/ma-code/temp_saves/local_inits/dr/sobol_w_$(N)_$(t_end)_$(M)_v2.jld2" sobol_w

# %% [markdown]
# #### müll

# %% [markdown]
# n
# - as expected, total index always greater than first order index
# - initial conditions rather insensitive
# - a is most sensitive parameter
# - si_a + si_m = 1 and total indices same as first order indices -> no significant interactions

# %% [markdown]
# w
# - TOI significantly higher than FOI -> apparently strong parameter interactions
# - qualitative behavior of FOI similar to n case
# - w0 least sensitive
# - n0 somehow sensitive
# - a most sensitive, m also quite sensitive
#
# Q: in local sensitivity  analysis w did not exhibit any sensitivity
