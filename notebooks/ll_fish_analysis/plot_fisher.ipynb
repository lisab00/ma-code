# %% [markdown]
# ## Plots of fisher information

# %% [markdown]
# Create fisher information plots like in
# "Roesch, E., & Stumpf, M. P. H. (2019). Parameter inference in dynamical systems with co-dimension 1 bifurcations. *Royal Society Open Science, 6*(190747). [https://doi.org/10.1098/rsos.190747](https://royalsocietypublishing.org/doi/pdf/10.1098/rsos.190747)"

# %%
import sys
sys.path.append('C:/Users/lisah/Documents/Repos/ma-code')
from src.plots_ll_fish import *

# %%
# generate all fisher plots

M_vals = [500]
noise_vals = [0.0, 0.1, 1.0]
m = 0.45 # fix for now as given by literature
w0 = 0.95 # mean(a_vals)
store = False
log = True
t_fixed = True

path_to_read= f"c:/Users/lisah/Documents/Repos/ma-code/data/t_fixed/t100/fisher/"
#path_to_read= f"c:/Users/lisah/Documents/Repos/ma-code/data/t_step/1.0/fisher/"
path_to_store = f"c:/Users/lisah/Documents/Repos/ma-code/plots/fisher/m{m}/"

make_all_fish_plots(M_vals, noise_vals, w0, m, path_to_read, path_to_store, t_fixed, store, log)

# %%
M_vals = [500,100, 50]
noise_vals = [0.1, 0.5, 1.0]
m = 0.45 # fix for now as given by literature
w0 = 0.95 # mean(a_vals)
store = False
log = True
t_fixed = True

path_to_read= f"c:/Users/lisah/Documents/Repos/ma-code/data/t_fixed/t50/fisher/"
#path_to_read= f"c:/Users/lisah/Documents/Repos/ma-code/data/t_step/1.0/fisher/"
path_to_store = f"c:/Users/lisah/Documents/Repos/ma-code/plots/fisher/m{m}/"

fish_grid_plot(noise_vals,M_vals,path_to_read, w0,m,log)

# %%
M = 500
noise = 0.0
w0=0.95
m=0.45

csv = read_fish_file(w0,m,M,noise, f"c:/Users/lisah/Documents/Repos/ma-code/data/t_fixed/t100/fisher/")
fig, ax = plt.subplots()
fi_avg_ic(fig, ax, csv)
#plt.savefig(f"c:/Users/lisah/Documents/Repos/ma-code/plots/fisher/m0.45/fish_ma_{w0}_{m}_{M}_{noise}.pdf", bbox_inches='tight')

# %%
fig, ax = plt.subplots()
ic = 1.0
fi_ic(fig, ax, csv, ic)
#plt.savefig(f"c:/Users/lisah/Documents/Repos/ma-code/plots/fisher/m0.45/fish_m{ic}_{w0}_{m}_{M}_{noise}.pdf", bbox_inches='tight')
# Out:
# (array([10]),)
